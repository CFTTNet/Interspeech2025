# %%
import os
import gc
import math
import logging
import warnings
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
from torch.nn.modules.rnn import LSTM, GRU
from torch.nn.modules.dropout import Dropout
from torch.nn.modules.linear import Linear
from torch.nn.modules.normalization import LayerNorm

import pytorch_lightning as pl
from torch.utils.data import Dataset, DataLoader
torch.set_float32_matmul_precision('medium')
# Auraloss
from auraloss.time import SISDRLoss
from auraloss.freq import MultiResolutionSTFTLoss

# Sound file
import soundfile as sf

import torchaudio
from tqdm import tqdm

# Complex modules
from cplxmodule.nn import CplxConv2d, CplxConvTranspose2d, CplxBatchNorm2d, CplxConv1d, CplxBatchNorm1d
from utils import *
from complexPyTorch.complexFunctions import complex_relu

# Lightning callbacks
from pytorch_lightning.callbacks import ModelCheckpoint, Callback

warnings.filterwarnings("ignore")
logging.getLogger('root').setLevel(logging.WARNING)

logging.basicConfig(level=logging.INFO)
epsilon = torch.finfo(torch.float32).eps

class CustomTQDMProgressBar(Callback): #custom pytorch lightening progress bar to display the real time progress to display the real time metrics such as SISDR, STFT, total loss, and LR
    """
    Displays a custom TQDM progress bar showing SISDR, STFT, total loss, and LR each batch.
    """
    def __init__(self): #calls constructor of the parent callback class to ensure proper initialization
        super().__init__()
        self.progress_bar = None #initializes the progress_bar attribute to none, this later hold the TQDM progress bar instance

    def on_train_epoch_start(self, trainer, pl_module): #initializes the tqdm progress bar at the start of the each training epoch, trainer object controlling training process, lightenig module being trained
        total_batches = trainer.num_training_batches #retrieves total number of training batches in the current epoch from the trainer
        # Create the progress bar for this epoch
        self.progress_bar = tqdm(
            total=total_batches, #total number of iterations of the progress bar equal to the total batches
            desc=f"Epoch {trainer.current_epoch + 1}/{trainer.max_epochs}", #descript prefix containing current epoch and total number of epochs
            leave=True  # keep the progress bar after the epoch is completed 
        )

    def on_train_batch_end(self, trainer, pl_module, outputs, batch, batch_idx):
        if self.progress_bar:
            # Grab the most recent losses from the module lists (or from `outputs` if you prefer)
            # Make sure pl_module.train_sisdr_epoch etc. actually have entries
            sisdr_val = pl_module.train_sisdr_epoch[-1].item() if pl_module.train_sisdr_epoch else 0.0
            stft_val  = pl_module.train_stft_epoch[-1].item()  if pl_module.train_stft_epoch  else 0.0
            total_val = pl_module.train_total_epoch[-1].item() if pl_module.train_total_epoch else 0.0

            # Current LR from the first optimizer
            current_lr = trainer.optimizers[0].param_groups[0]['lr']

            # Update TQDM postfix
            self.progress_bar.set_postfix({
                'SISDR': f"{sisdr_val:.4f}",
                'STFT': f"{stft_val:.4f}",
                'Total': f"{total_val:.4f}",
                'LR': f"{current_lr:.2e}"
            })
            self.progress_bar.update(1)

    def on_train_epoch_end(self, trainer, pl_module):
        if self.progress_bar:
            self.progress_bar.close()
            self.progress_bar = None

# -------------- Utility function to save wav -------------- #
def save_wav(audio_data, sr, filepath):
    try:
        sf.write(filepath, audio_data, sr)
        logging.info(f"Saved WAV file: {filepath}")
    except Exception as e:
        logging.error(f"Failed to save WAV file {filepath}: {e}", exc_info=True)

# -------------- Dataset for 4s Clipped WAVs -------------- #
class FourSecDataset(Dataset): #pytorch's dataset class inheritance, make it compatible to pytorch's data loading mechanisms such as data loader
    """
    Loads the already preprocessed 4-second clips from disk.
    Expects to find filenames like:
        acc_<something>.wav
        clean_<something>.wav
    in the same directory.

    This does NOT do filtering/resampling/padding, because
    it expects data is already prepared exactly as 4s, 16kHz.
    """
    def __init__(self, root_4s_dir, mode='acc', sample_rate=48000): #root directory where the audios are stored, find acc and pair with clean, sampling rate = 48000 
        super().__init__() #base class inheritance
        # 'mode' can be 'acc' or 'clean', but typically we find pairs.
        self.root_4s_dir = root_4s_dir #directory path and sample rate store 
        self.sample_rate = sample_rate #expected sample rate for verification

        # For example, gather only 'acc_' files, but we'll pair them with 'clean_' on the fly
        self.acc_files = sorted([
            f for f in os.listdir(root_4s_dir) if f.startswith('acc_') and f.lower().endswith('.wav') #list all the files start with acc and ends with .wav, sorting ensure consistent ordering
        ])
        if len(self.acc_files) == 0: #if do not find any acc files in the directory then raise error
            raise RuntimeError(f"No 'acc_' wav files found in {root_4s_dir}!")

    def __len__(self): #return the length or the number of acc files in the directory, which is essential for batching and iteration
        return len(self.acc_files)

    def __getitem__(self, idx):
        acc_filename = self.acc_files[idx]
        # e.g. "acc_speaker_001.wav" -> "clean_speaker_001.wav"
        clean_filename = acc_filename.replace('acc_', 'clean_')

        acc_path = os.path.join(self.root_4s_dir, acc_filename)
        clean_path = os.path.join(self.root_4s_dir, clean_filename)

        # Load them
        acc_wav, sr = torchaudio.load(acc_path)
        clean_wav, sr2 = torchaudio.load(clean_path)

        # Optional: verify sample rates if needed
        if sr != sr2 or sr != self.sample_rate:
            raise RuntimeError(f"Inconsistent sample rates. {acc_path}:{sr}, {clean_path}:{sr2} "
                               f"(expected {self.sample_rate})")

        # Both should be shape [1, T]
        return {
            'acc': acc_wav,
            'clean': clean_wav,
            'filename': acc_filename  # e.g. we store the ACC file name
        }
class CplxLinear(nn.Module): #custom nn to handle complex-valued inputs and perform linear transformations
    def __init__(self, in_features, out_features, bias=True): #number of input and output features and whether to include a bias term in the linear transformation
        super(CplxLinear, self).__init__()
        self.real_linear = nn.Linear(in_features, out_features, bias=bias) #real valued linear layer which will process the real parts of the complex input
        self.imag_linear = nn.Linear(in_features, out_features, bias=bias) #imaginary valued linear layer which will process the imaginary parts of the complex input
    
    def forward(self, input): #w⋅z=(a+ib)(x+iy)=(ax−by)+i(ay+bx)
        # Assuming input is a ComplexTensor with .real and .imag attributes
        real = self.real_linear(input.real) - self.imag_linear(input.imag) #real = Weight_real * input.real - Weight_imag * input.imag + bias_real
        imag = self.real_linear(input.imag) + self.imag_linear(input.real) #imaginary = Weight_real * input.imag + Weight_imaginary * input.real + bias_imaginary
        return ComplexTensor(real, imag)
    
    
class ComplexEncoder(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size=(3, 3), stride=(2, 1), padding=(1, 1), bias=False,
                 DSC=False):
        super(ComplexEncoder, self).__init__()
        # DSC: depthwise_separable_conv
        if DSC:
            self.conv = DSC_Encoder(in_channels, out_channels, kernel_size=kernel_size, stride=stride, padding=padding,
                                    bias=bias)
        else:
            self.conv = CplxConv2d(in_channels, out_channels, kernel_size=kernel_size, stride=stride, padding=padding,
                                   bias=bias)
        self.norm = CplxBatchNorm2d(out_channels)

    def forward(self, x):
        return complex_relu(self.norm(self.conv(x)))


class ComplexDecoder(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1),
                 output_padding=(0, 0), bias=False, DSC=False):
        super(ComplexDecoder, self).__init__()
        # DSC: depthwise_separable_conv
        if DSC:
            self.conv = DSC_Decoder(in_channels, out_channels, kernel_size=kernel_size, stride=stride, padding=padding,
                                    output_padding=output_padding, bias=bias)
        else:
            self.conv = CplxConvTranspose2d(in_channels, out_channels, kernel_size=kernel_size, stride=stride,
                                            padding=padding, output_padding=output_padding, bias=bias)

        self.norm = CplxBatchNorm2d(out_channels)

    def forward(self, x):
        return complex_relu(self.norm(self.conv(x)))


class DSC_Encoder(nn.Module):
    # depthwise_separable_conv
    def __init__(self, in_channels, out_channels, kernel_size=3, stride=(2, 1), padding=(1, 1), bias=False):
        super(DSC_Encoder, self).__init__()
        self.depthwise = CplxConv2d(in_channels, in_channels, kernel_size=kernel_size, stride=stride, padding=padding,
                                    groups=in_channels, bias=bias)
        self.pointwise = CplxConv2d(in_channels, out_channels, kernel_size=1, bias=bias)

    def forward(self, x):
        out = self.depthwise(x)
        out = self.pointwise(out)
        return out


class DSC_Decoder(nn.Module):
    # depthwise_separable_conv
    def __init__(self, in_channels, out_channels, kernel_size=3, stride=(2, 1), padding=(1, 1), output_padding=(0, 0),
                 bias=False):
        super(DSC_Decoder, self).__init__()
        self.depthwise = CplxConvTranspose2d(in_channels, in_channels, kernel_size=kernel_size, stride=stride,
                                             padding=padding, groups=in_channels, output_padding=output_padding,
                                             bias=bias)
        self.pointwise = CplxConvTranspose2d(in_channels, out_channels, kernel_size=1, bias=bias)

    def forward(self, x):
        out = self.depthwise(x)
        out = self.pointwise(out)
        return out

# ===================== ComplexGRU =====================
class ComplexGRU(nn.Module): #inherits from nn.module, which is foundational class for all NN modules in PyTorch
    def __init__(self, input_size, output_size, num_layers): #ComplexGRU integrate with pytorch components,  #number of expected features in input, output 
        super(ComplexGRU, self).__init__()
        self.rGRU = nn.Sequential(
            nn.GRU(input_size=input_size, hidden_size=input_size // 2, num_layers=num_layers, batch_first=True, bidirectional=True)),  #input and output is provided in the following batch, sequence, feature 
      
        self.iGRU = nn.Sequential(
            nn.GRU(input_size=input_size, hidden_size=input_size // 2, num_layers=num_layers, batch_first=True,
                   bidirectional=True), 
            SelectItem(0) #hidden state will be discarded, only output will selected
        )
        self.linear = CplxLinear(input_size, output_size) #complex linear transformation to convert GRU outputs from input_size to output_size

    def forward(self, x):
        # x shape: [B, channel, T, F], but we typically pass [B, channel, T], or something similar
        x = x.transpose(-1, -2).contiguous()  # [B, channel, T, F] --> [B, channel, F, T | Contiguous ensures that tensor is stored in a contiguous chunk of memory for efficient computation
        real = self.rGRU(x.real) - self.iGRU(x.imag) 
        imag = self.rGRU(x.imag) + self.iGRU(x.real)
        out = self.linear(ComplexTensor(real, imag)).transpose(-1, -2)
        return out

# Step: 4.2 --------------------  Complex Conformer layers --------------------------


class ConformerEncoderLayer(nn.Module):
    def __init__(self, num_heads = 8, d_model = 1, dff = 256, dropout = 0.1):
        super(ConformerEncoderLayer, self).__init__()
        self.d_model = d_model #dimension of input and output features
        self.num_heads = num_heads #number of attention head in multi-head attention
        self.dff = dff #dimensionality of feedforward network's hidden layer
        self.dropout = dropout #dropout rate = 0.1
        
        # Multi-Head Self Attention: batch_first=True => input shape is (B, T, C)
        self.mha = nn.MultiheadAttention(embed_dim=d_model, 
                                         num_heads=num_heads, 
                                         batch_first=True)
        
        # 1D Convolutions
        # Keras default shape is (B, T, C); PyTorch uses (B, C, T)
        # We'll rearrange dimensions in forward().
        self.conv1 = nn.Conv1d(in_channels=d_model, 
                               out_channels=d_model, 
                               kernel_size=1)
        self.conv2 = nn.Conv1d(in_channels=d_model, 
                               out_channels=d_model, 
                               kernel_size=1)
        
        # Feed-Forward Network
        #To capture complex, non-linear relationships
        self.ffn = nn.Sequential(
            nn.Linear(d_model, dff),
            nn.ReLU(),
            nn.Linear(dff, d_model)
        )
        
        # Layer Normalizations to stabilizes and accelerates the training of DNN by normalizing across the features
        self.layernorm1 = nn.LayerNorm(d_model, eps=1e-6) 
        self.layernorm2 = nn.LayerNorm(d_model, eps=1e-6)
        
        # Dropouts regularizes by preventing 
        self.dropout1 = nn.Dropout(dropout)
        self.dropout2 = nn.Dropout(dropout)

    def forward(self, x):
        """
        Args:
            x: Tensor of shape (batch_size, seq_len, d_model)
        Returns:
            out4: Tensor of shape (batch_size, seq_len, d_model)
        """

        # First Feed Forward
        ffn_output = self.ffn(x)
        out1 = self.layernorm1(x + ffn_output)  # Add & Norm

        # Self-Attention
        attn_output, _ = self.mha(out1, out1, out1) #why 3? query, key, value
        #q,k,v assigned same value (out1) making it a self-attention mechanism
        #_discards attention weights returned by the mha function, can be used in analysis or visualization
        
        attn_output = self.dropout1(attn_output) #dropout to prevent overfitting
        out2 = self.layernorm2(out1 + attn_output)  # Add & Norm

        # Convolution 1
        # Switch to (B, C, T) for Conv1d
        conv1_input = out2.permute(0, 2, 1)
        conv1_output = self.conv1(conv1_input)
        #conv1_output = self.conv1(out2)
        conv1_output = F.relu(conv1_output)
        # Switch back to (B, T, C)
        conv1_output = conv1_output.permute(0, 2, 1)

        # Convolution 2
        conv2_output = conv1_output.permute(0, 2, 1)
        conv2_output = self.conv2(conv2_output)
        conv2_output = F.relu(conv2_output)
        conv2_output = conv2_output.permute(0, 2, 1)
        
        # Another Add & Norm (reusing layernorm2 to match TF code)
        out3 = self.layernorm2(out2 + conv2_output)

        # Second Feed Forward
        ffn_output = self.ffn(out3)
        ffn_output = self.dropout2(ffn_output)
        out4 = self.layernorm2(out3 + ffn_output)  # Add & Norm
        
        return out4
class Conformer_single(nn.Module):
    """
    Encapsulates a single Conformer encoder layer and applies it to the input tensor
    after appropriate reshaping and permutation.

    Args:
        d_model (int): The number of expected features in the input (F).
        num_heads (int): The number of heads in the multiheadattention models.
    """
    def __init__(self, num_heads=8, d_model = 1, dff = 256, dropout = 0.1):
        super(Conformer_single, self).__init__()
        self.conformer_encoder_layer = ConformerEncoderLayer(
            num_heads=num_heads,
            d_model = d_model,
            dff = dff,
            dropout = dropout
        )
    def forward(self, x):
        """
        Forward pass of the Conformer_single module.

        Args:
            x (torch.Tensor): Input tensor of shape [batch, Ch, F, T]

        Returns:
            torch.Tensor: Output tensor of shape [batch, Ch, F, T]
        """
        # x shape: [batch, Ch, F, T]
        b, c, F, T = x.shape

        # Permute and reshape to [Ch, batch*T, F] for the Conformer
        x = x.permute(1, 0, 3, 2).contiguous().view(c, b * T, F)  # [Ch, batch*T, F]

        # Pass through the Conformer encoder layer
        x = self.conformer_encoder_layer(x)  # [Ch, batch*T, F]

        # Reshape back to [batch, Ch, F, T]
        x = x.view(c, b, T, F).permute(1, 0, 3, 2).contiguous()  # [batch, Ch, F, T]

        return x
class Conformer_multi(nn.Module):
    # d_model = x.shape[3]
    def __init__(self, num_heads = 8, layer_num=2, d_model = 1, dff = 256, dropout = 0.1):
        super(Conformer_multi, self).__init__()
        self.layer_num = layer_num
        self.MTB = Conformer_single(num_heads=num_heads, d_model = d_model, dff = dff, dropout = dropout)  # d_model: the number of expected features in the input

    def forward(self, x):
        for i in range(self.layer_num):
            x = self.MTB(x)
        return x   

class ComplexConformer(nn.Module):
    def __init__(self, num_heads=1, num_layers=2, d_model=1, dff=256, dropout=0.1):
        super(ComplexConformer, self).__init__()
        self.rTrans = Conformer_multi(num_heads=num_heads, layer_num=num_layers, d_model = d_model, dff = dff, dropout = dropout)  # d_model = x.shape[3]
        self.iTrans = Conformer_multi(num_heads=num_heads, layer_num=num_layers, d_model = d_model, dff = dff, dropout = dropout)  # d_model = x.shape[3]
        # self.Trans = Conformer_multi(num_heads=17, layer_num=num_layer)

    def forward(self, x):
        # real = self.Trans(x.real)
        # imag = self.Trans(x.imag)
        real = self.rTrans(x.real) - self.iTrans(x.imag)
        imag = self.rTrans(x.imag) + self.iTrans(x.real)
        out = ComplexTensor(real, imag)  # .contiguous()
        return out


# ===================== TTB Blocks =====================
class NodeReshape(nn.Module):
    def __init__(self, shape):
        super(NodeReshape, self).__init__()
        self.shape = shape

    def forward(self, feature_in: torch.Tensor):
        shape = feature_in.size()
        batch = shape[0]
        new_shape = [batch]
        new_shape.extend(list(self.shape))
        return feature_in.reshape(new_shape)

class Freq_FC(nn.Module):
    def __init__(self, F_dim, bias=False):
        super(Freq_FC, self).__init__()
        self.linear = CplxLinear(F_dim, F_dim, bias=bias)

    def forward(self, x):
        out = x.transpose(-1, -2).contiguous()  # [batch, channel_in_out, T, F]
        out = self.linear(out)  # .contiguous()
        out = torch.complex(out.real, out.imag)
        out = out.transpose(-1, -2).contiguous()  # [batch, channel_in_out, F, T]
        return out


class ComplexFTB(torch.nn.Module):
    """docstring for FTB"""

    def __init__(self, F_dim, channels):
        super(ComplexFTB, self).__init__()
        self.channels = channels
        self.C_r = 5
        self.F_dim = F_dim

        self.Conv2D_1 = nn.Sequential(
            CplxConv2d(in_channels=self.channels, out_channels=self.C_r, kernel_size=1, stride=1, padding=0),
            CplxBatchNorm2d(self.C_r),

        )
        self.Conv1D_1 = nn.Sequential(
            CplxConv1d(self.F_dim * self.C_r, self.F_dim, kernel_size=9, padding=4),
            CplxBatchNorm1d(self.F_dim),
        )
        self.FC = Freq_FC(self.F_dim, bias=False)
        self.Conv2D_2 = nn.Sequential(
            CplxConv2d(2 * self.channels, self.channels, kernel_size=1, stride=1, padding=0),
            CplxBatchNorm2d(self.channels),
        )

        self.att_inner_reshape = NodeReshape([self.F_dim * self.C_r, -1])
        self.att_out_reshape = NodeReshape([1, F_dim, -1])

    def cat(self, x, y, dim):
        real = torch.cat([x.real, y.real], dim)
        imag = torch.cat([x.imag, y.imag], dim)
        return ComplexTensor(real, imag)

    def forward(self, inputs, verbose=False):
        # feature_n: [batch, channel_in_out, T, F]
        if verbose: print('Displaying FTB shape', ) 
        _, _, self.F_dim, self.T_dim = inputs.shape
        # Conv2D
        out = complex_relu(self.Conv2D_1(inputs));
        if verbose: print('Layer-1               : ', out.shape)  # [B,Cr,T,F]
        # Reshape: [batch, channel_attention, F, T] -> [batch, channel_attention*F, T]
        out = out.view(out.shape[0], out.shape[1] * out.shape[2], out.shape[3])
        # out = self.att_inner_reshape(out);
        if verbose: print('Layer-2               : ', out.shape)
        # out = out.view(-1, self.T_dim, self.F_dim * self.C_r) ; print(out.shape) # [B,c_ftb_r*f,segment_length]
        # Conv1D
        out = complex_relu(self.Conv1D_1(out));
        if verbose: print('Layer-3               : ', out.shape)  # [B,F, T]
        # temp = self.att_inner_reshape(temp); print(temp.shape)
        out = out.unsqueeze(1)
        # out = out.view(-1, self.channels, self.F_dim, self.T_dim);
        if verbose: print('Layer-4               : ', out.shape)  # [B,c_a,segment_length,1]
        # Multiplication with input
        out = out * inputs;
        
        if verbose: print('Layer-5               : ', out.shape)  # [B,c_a,segment_length,1]*[B,c_a,segment_length,f]
        # Frequency- FC
        # out = torch.transpose(out, 2, 3)  # [batch, channel_in_out, T, F]
        out = self.FC(out);
        # if verbose: print('Layer-6               : ', out.shape)  # [B,c_a,segment_length,f]
        # out = torch.transpose(out, 2, 3)  # [batch, channel_in_out, T, F]
        # Concatenation with Input
        out = self.cat(out, inputs, 1);
        if verbose: print('Layer-7               : ', out.shape)  # [B,2*c_a,segment_length,f]
        # Conv2D
        outputs = complex_relu(self.Conv2D_2(out));
        if verbose: print('Layer-8               : ', outputs.shape)  # [B,c_a,segment_length,f]

        return outputs
    
class Time_FC(nn.Module):
    def __init__(self, T_dim, bias=False):
        super(Time_FC, self).__init__()
        self.linear = CplxLinear(T_dim, T_dim, bias=bias)

    def forward(self, x):
        # x shape [batch, channel, T, F], we'll transpose to [batch, channel, F, T]
        out = x.transpose(-1, -2).contiguous()  # [B, C, F, T]
        out = self.linear(out)
        out = torch.complex(out.real, out.imag)
        out = out.transpose(-1, -2).contiguous()  # [B, C, T, F]
        return out


class ComplexTTB(torch.nn.Module):
    """docstring for TTB"""

    def __init__(self, T_dim, channels):
        super(ComplexTTB, self).__init__()
        self.channels = channels
        self.C_r = 5
        self.T_dim = T_dim

        self.Conv2D_1 = nn.Sequential(
            CplxConv2d(in_channels=self.channels, out_channels=self.C_r, kernel_size=1, stride=1, padding=0),
            CplxBatchNorm2d(self.C_r),

        )
        self.Conv1D_1 = nn.Sequential(
            CplxConv1d(self.T_dim * self.C_r, self.T_dim, kernel_size=9, padding=4),
            CplxBatchNorm1d(self.T_dim),
        )
        self.FC = Time_FC(self.T_dim, bias=False)
        self.Conv2D_2 = nn.Sequential(
            CplxConv2d(2 * self.channels, self.channels, kernel_size=1, stride=1, padding=0),
            CplxBatchNorm2d(self.channels),
        )

        self.att_inner_reshape = NodeReshape([self.T_dim * self.C_r, -1])
        self.att_out_reshape = NodeReshape([1, T_dim, -1])

    def cat(self, x, y, dim):
        real = torch.cat([x.real, y.real], dim)
        imag = torch.cat([x.imag, y.imag], dim)
        return ComplexTensor(real, imag)

    def forward(self, inputs, verbose=False):
        # feature_n: [batch, channel_in_out, T, F]
        if verbose: print('Displaying TTB shape', ) 
        _, _, self.F_dim, self.T_dim = inputs.shape
        # Conv2D
        out = complex_relu(self.Conv2D_1(inputs));
        if verbose: print('Layer-1               : ', out.shape)  # [B,Cr,T,F]
        # Reshape: [batch, channel_attention, F, T] -> [batch, channel_attention*F, T]
        out = out.view(out.shape[0], out.shape[1] * out.shape[3], out.shape[2])
        # out = self.att_inner_reshape(out);
        if verbose: print('Layer-2               : ', out.shape)
        # out = out.view(-1, self.T_dim, self.F_dim * self.C_r) ; print(out.shape) # [B,c_ttb_r*f,segment_length]
        # Conv1D
        out = complex_relu(self.Conv1D_1(out));
        if verbose: print('Layer-3               : ', out.shape)  # [B,F, T]
        # temp = self.att_inner_reshape(temp); print(temp.shape)
        out = out.unsqueeze(1)
        # out = out.view(-1, self.channels, self.F_dim, self.T_dim);
        if verbose: print('Layer-4               : ', out.shape)  # [B,c_a,segment_length,1]
        # Multiplication with input
        out = out * inputs.transpose(-1, -2);
        if verbose: print('Layer-5               : ', out.shape)  # [B,c_a,segment_length,1]*[B,c_a,segment_length,f]
        # Frequency- FC
        # out = torch.transpose(out, 2, 3)  # [batch, channel_in_out, T, F]
        out = self.FC(out);
        # if verbose: print('Layer-6               : ', out.shape)  # [B,c_a,segment_length,f]
        # out = torch.transpose(out, 2, 3)  # [batch, channel_in_out, T, F]
        # Concatenation with Input
        out = self.cat(out.transpose(-1, -2), inputs, 1);
        if verbose: print('Layer-7               : ', out.shape)  # [B,2*c_a,segment_length,f]
        # Conv2D
        outputs = complex_relu(self.Conv2D_2(out));
        if verbose: print('Layer-8               : ', outputs.shape)  # [B,c_a,segment_length,f]

        return outputs

# -------------------------------- Depth wise Seperable Convolution --------------------------------
class depthwise_separable_convx(nn.Module):
    def __init__(self, nin, nout, kernel_size=3, padding=1, bias=False):
        super(depthwise_separable_convx, self).__init__()
        self.depthwise = nn.Conv2d(nin, nin, kernel_size=kernel_size, padding=padding, groups=nin, bias=bias)
        self.pointwise = nn.Conv2d(nin, nout, kernel_size=1, bias=bias)

    def forward(self, x):
        out = self.depthwise(x)
        out = self.pointwise(out)
        return out


# ===================== Skip Blocks / Connections =====================
class SkipBlock(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size=3, stride=1, padding=1, DSC=False):
        super(SkipBlock, self).__init__()
        if DSC:
            self.conv = DSC_Encoder(in_channels, out_channels, kernel_size=kernel_size, stride=stride,
                                    padding=padding, bias=True)
        else:
            self.conv = CplxConv2d(in_channels, out_channels, kernel_size=kernel_size, stride=stride,
                                   padding=padding, bias=True)
        self.norm = CplxBatchNorm2d(in_channels)

    def forward(self, x):
        return complex_relu(self.norm(self.conv(x))) + x


class SkipConnection(nn.Module):
    """
    SkipConnection is a concatenation of SkipBlocks
    """
    def __init__(self, in_channels, num_convblocks, DSC=False):
        super(SkipConnection, self).__init__()
        self.skip_blocks = nn.ModuleList([
            SkipBlock(in_channels, in_channels, kernel_size=3, stride=1, padding=1, DSC=DSC)
            for _ in range(num_convblocks)
        ])

    def forward(self, x):
        out = x
        for block in self.skip_blocks:
            out = block(out)
        return out

# ===================== CFTNet Model Definition =====================
class DCCTN(torch.nn.Module):
    """
    TTBComplexSkipConvNet + Conformer
    Complex Skip convolution
    It uses only two TTB layers; one in the first layer and one in the last layer
    Instead of using LSTM, it uses Conformer
    """

    def __init__(self, L=256, N=256, H=128, Mask=[5, 7], B=24, F_dim = 129, T_dim=1499):
        super().__init__()
        self.name = 'DCCTN'  # 'TTBTxComplexSkipConvNet2'
        self.f_taps = list(range(-Mask[0] // 2 + 1, Mask[0] // 2 + 1))
        self.t_taps = list(range(-Mask[1] // 2 + 1, Mask[1] // 2 + 1))

        self.stft = STFT(frame_len=L, frame_hop=H, num_fft=N)
        self.istft = iSTFT(frame_len=L, frame_hop=H, num_fft=N)

        self.enc1 = ComplexEncoder(1, 1 * B, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=True)
        self.FTB1 = ComplexFTB(math.ceil(F_dim / 2), channels=1 * B)  # First FTB layer
        self.TTB1 = ComplexTTB(math.ceil(T_dim / 2), channels=1 * B)  # First TTB layer
        
        self.Conv2D_1 = nn.Sequential(
            CplxConv2d(3*B, 1*B, kernel_size=1, stride=1, padding=0),
            CplxBatchNorm2d(1*B),
        )
        
        self.enc2 = ComplexEncoder(1 * B, 2 * B, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=True)
       
        self.enc3 = ComplexEncoder(2 * B, 2 * B, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=True)
      
        self.enc4 = ComplexEncoder(2 * B, 3 * B, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=True)
       
        self.enc5 = ComplexEncoder(3 * B, 3 * B, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=True)
        
        self.enc6 = ComplexEncoder(3 * B, 4 * B, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=True)
       
        self.enc7 = ComplexEncoder(4 * B, 4 * B, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=True)
        self.FTB7 = ComplexFTB(math.ceil(F_dim / 128), channels=4 * B)  # last FTB layer
        self.TTB7 = ComplexTTB(math.ceil(T_dim / 128), channels=4 * B)  # last TTB layer
        
        self.Conv2D_2 = nn.Sequential(
            CplxConv2d(3* 4* B, 4*B, kernel_size=1, stride=1, padding=0),
            CplxBatchNorm2d(4*B),
        )
        
        self.enc8 = ComplexEncoder(4 * B, 8 * B, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=True)
        self.conformer = ComplexConformer(num_heads=1, num_layers=2, d_model=1, dff=256, dropout=0.1)
        self.GRU = ComplexGRU(8 * B, 8 * B, num_layers=2)

        self.skip1 = SkipConnection(8 * B, num_convblocks=4)
        self.skip2 = SkipConnection(4 * B, num_convblocks=4)
        self.skip3 = SkipConnection(4 * B, num_convblocks=3)
        self.skip4 = SkipConnection(3 * B, num_convblocks=3)
        self.skip5 = SkipConnection(3 * B, num_convblocks=2)
        self.skip6 = SkipConnection(2 * B, num_convblocks=2)
        self.skip7 = SkipConnection(2 * B, num_convblocks=1)
        self.skip8 = SkipConnection(1 * B, num_convblocks=1)

        self.dec1 = ComplexDecoder(16 * B, 8 * B, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=True, output_padding=(1, 1))
        self.dec2 = ComplexDecoder(12 * B, 8 * B, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(0,1), bias=True)
        self.dec3 = ComplexDecoder(12 * B, 4 * B, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1),  output_padding=(0, 0), bias=True)
        self.dec4 = ComplexDecoder(7 * B, 3 * B, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1),  output_padding=(0, 1), bias=True)
        self.dec5 = ComplexDecoder(6 * B, 3 * B, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1),  output_padding=(0, 1), bias=True)
        self.dec6 = ComplexDecoder(5 * B, 2 * B, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1),  output_padding=(0, 0), bias=True)
        self.dec7 = ComplexDecoder(4 * B, 2 * B, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1),  output_padding=(0, 1), bias=True)
        self.dec8 = ComplexDecoder(3 * B, Mask[0] * Mask[1], kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(0, 0), bias=True)

    def cat(self, x, y, dim):
        real = torch.cat([x.real, y.real], dim)
        imag = torch.cat([x.imag, y.imag], dim)
        return ComplexTensor(real, imag)

    def deepfiltering(self, deepfilter, cplxInput):
        deepfilter = deepfilter.permute(0, 2, 3, 1)
        real_tf_shift = torch.stack(
            [torch.roll(cplxInput.real, (i, j), dims=(1, 2)) for i in self.f_taps for j in self.t_taps], 3).transpose(
            -1, -2)
        imag_tf_shift = torch.stack(
            [torch.roll(cplxInput.imag, (i, j), dims=(1, 2)) for i in self.f_taps for j in self.t_taps], 3).transpose(
            -1, -2)
        imag_tf_shift += 1e-10
        cplxInput_shift = ComplexTensor(real_tf_shift, imag_tf_shift)
        est_complex = einsum('bftd,bfdt->bft', [deepfilter.conj(), cplxInput_shift])
        return est_complex

    def forward(self, audio, verbose=False):
        """
        batch: tensor of shape (batch_size x channels x num_samples)
        """
        if verbose: print('*' * 60)
        if verbose: print('Input Audio Shape         : ', audio.shape)
        if verbose: print('*' * 60)

        _, _, real, imag = self.stft(audio)
        cplxIn = ComplexTensor(real, imag)
        if verbose: print('STFT Complex Spec         : ', cplxIn.shape)

        if verbose: print('\n' + '-' * 20)
        if verbose: print('Encoder Network')
        if verbose: print('-' * 20)

        enc1 = self.enc1(cplxIn.unsqueeze(1))
        if verbose: print('Encoder-1                 : ', enc1.shape)
        
        FTB1 = self.FTB1(enc1)
        if verbose: print('FTB-1 output shape              : ', FTB1.shape)
        
        TTB1 = self.TTB1(enc1)
        if verbose: print('TTB-1 output shape         : ', TTB1.shape)
        
        FTTB_parallel1 = self.cat(FTB1, TTB1, 1)
        if verbose: print('FTTB_parallel1 shape', FTTB_parallel1.shape) 
        
        FTTB_parallel_skip_1 = self.cat(enc1, FTTB_parallel1, 1)
        if verbose: print('FTTB_parallel_skip_1 shape', FTTB_parallel_skip_1.shape) 
        
        FTTB_parallel_skip_1_conv = self.Conv2D_1(FTTB_parallel_skip_1)
        if verbose: print('FTTB_parallel_skip_1_conv shape', FTTB_parallel_skip_1_conv.shape) 
        
        enc2 = self.enc2(FTTB_parallel_skip_1_conv)
        if verbose: print('Encoder-2                 : ', enc2.shape)
        
        enc3 = self.enc3(enc2)
        if verbose: print('Encoder-3                 : ', enc3.shape)
        
        enc4 = self.enc4(enc3)
        if verbose: print('Encoder-4                 : ', enc4.shape)
        
        enc5 = self.enc5(enc4)
        if verbose: print('Encoder-5                 : ', enc5.shape)
        
        enc6 = self.enc6(enc5)
        if verbose: print('Encoder-6                 : ', enc6.shape)
        
        enc7 = self.enc7(enc6)
        if verbose: print('Encoder-7                 : ', enc7.shape)
        
        FTB7 = self.FTB7(enc7)
        if verbose: print('FTB-7 output shape            : ', FTB7.shape)
        
        TTB7 = self.TTB7(enc7)
        if verbose: print('TTB-7 output shape          : ', TTB7.shape)
        
        
        FTTB_parallel2 = self.cat(FTB7, TTB7, 1)
        if verbose: print('FTTB_parallel2             : ', FTTB_parallel2.shape)
        
        FTTB_parallel_skip_2 = self.cat(enc7, FTTB_parallel2, 1)
        if verbose: print('FTTB_parallel_skip_2: ', FTTB_parallel_skip_2.shape)
        
        FTTB_parallel_skip_2_conv = self.Conv2D_2(FTTB_parallel_skip_2)
        if verbose: print('FTTB_parallel_skip_2_conv: ', FTTB_parallel_skip_2_conv.shape)
        enc8 = self.enc8(FTTB_parallel_skip_2_conv)
        if verbose: print('Encoder-8                 : ', enc8.shape)

        # +++++++++++++++++++ Expanding Path  +++++++++++++++++++++ #

        MLTB = self.conformer(enc8)
        if verbose: print('Conformer-1               : ', MLTB.shape)
        if verbose: print('\n' + '-' * 20)
        if verbose: print('Decoder Network')
        if verbose: print('-' * 20)
        dec = self.dec1(self.cat(MLTB, self.skip1(enc8), 1))
        # ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

        if verbose: print('Decoder-1                 : ', dec.shape)
        dec = self.dec2(self.cat(dec, self.skip2(enc7), 1))
        if verbose: print('Decoder-2                 : ', dec.shape)
        dec = self.dec3(self.cat(dec, self.skip3(enc6), 1))
        if verbose: print('Decoder-3                 : ', dec.shape)
        dec = self.dec4(self.cat(dec, self.skip4(enc5), 1))
        if verbose: print('Decoder-4                 : ', dec.shape)
        dec = self.dec5(self.cat(dec, self.skip5(enc4), 1))
        if verbose: print('Decoder-5                 : ', dec.shape)
        dec = self.dec6(self.cat(dec, self.skip6(enc3), 1))
        if verbose: print('Decoder-6                 : ', dec.shape)
        dec = self.dec7(self.cat(dec, self.skip7(enc2), 1))
        if verbose: print('Decoder-7                 : ', dec.shape)
        dec = self.dec8(self.cat(dec, self.skip8(enc1), 1))
        if verbose: print('Decoder-8                 : ', dec.shape)

        deepfilter = ComplexTensor(dec.real, dec.imag)
        enhanced = self.deepfiltering(deepfilter, cplxIn)
        enh_mag, enh_phase = enhanced.abs(), enhanced.angle()
        audio_enh = self.istft(enh_mag, enh_phase, squeeze=True)
        if verbose: print('*' * 60)
        if verbose: print('Output Audio Shape        : ', audio_enh.shape)
        if verbose: print('*' * 60)

        return audio_enh
    
class SelectItem(nn.Module):
    """Select item [0] from the tuple returned by e.g. GRU output"""
    def __init__(self, idx=0):
        super().__init__()
        self.idx = idx

    def forward(self, x):
        return x[self.idx]

# -------------- Lightning Module -------------- #
class DeepLearningModel(pl.LightningModule):
    def __init__(self, net, batch_size=1, save_sample_outputs=False, save_dir='enhanced_samples'):
        super().__init__()
        self.model = net
        self.batch_size = batch_size
        self.save_sample_outputs = save_sample_outputs
        self.save_dir = save_dir

        # Loss functions
        self.si_sdr_loss = SISDRLoss()
        self.stft_loss_func = MultiResolutionSTFTLoss(
            fft_sizes=[256, 512, 1024],
            hop_sizes=[128, 256, 512],
            win_lengths=[256, 512, 1024],
            scale=None,
            n_bins=128,
            sample_rate=48000,
            perceptual_weighting=False,
        )
        os.makedirs(self.save_dir, exist_ok=True)

        # For storing epoch-level losses
        self.train_sisdr_log = []
        self.train_stft_log = []
        self.train_total_log = []
        self.val_sisdr_log = []
        self.val_stft_log = []
        self.val_total_log = []
        self.train_sisdr_epoch = []
        self.train_stft_epoch = []
        self.train_total_epoch = []
        self.val_sisdr_epoch = []
        self.val_stft_epoch = []
        self.val_total_epoch = []

        self.log_file = os.path.join(self.save_dir, "loss_logs.txt")

    def forward(self, x):
        return self.model(x)

    def compute_losses(self, pred, target):
        """
        Compute SISDR and Multi-Resolution STFT losses separately + total.
        Expect shape [B, T] or [B, 1, T].
        Make sure we always convert to [B, 1, T] for Auraloss.
        """
        # If shape is [T], add a batch dimension => [1, T]
        if pred.dim() == 1:
            pred = pred.unsqueeze(0)
        if target.dim() == 1:
            target = target.unsqueeze(0)

        # If shape is [B, T], add a channel dimension => [B, 1, T]
        if pred.dim() == 2:
            pred = pred.unsqueeze(1)
        if target.dim() == 2:
         target = target.unsqueeze(1)
        
        #target = torch.clamp(target, min=-1, max=1.0)
        #pred   = torch.clamp(pred,   min=-1.0, max=1.0)

        # Now pred & target are [B, 1, T]. 
        sisdr = self.si_sdr_loss(target, pred)
        freq_loss = self.stft_loss_func(pred, target) 
        total = sisdr + freq_loss
        return sisdr, freq_loss, total

    def training_step(self, batch, batch_idx):
        acc_data = batch['acc']
        clean_data = batch['clean']

        enh_audio = self(acc_data)
        sisdr_loss, stft_loss, total_loss = self.compute_losses(enh_audio, clean_data)

        self.train_sisdr_epoch.append(sisdr_loss)
        self.train_stft_epoch.append(stft_loss)
        self.train_total_epoch.append(total_loss)

        self.log('train_sisdr_step', sisdr_loss, on_step=True)
        self.log('train_stft_step', stft_loss, on_step=True)
        self.log('train_total_step', total_loss, on_step=True)

        # Optionally save some examples
        if self.save_sample_outputs and (batch_idx < 5):
            filenames = batch['filename']
            for i in range(acc_data.size(0)):
                enhanced = enh_audio[i].detach().cpu().numpy().squeeze()
                base_name = os.path.splitext(filenames[i])[0]
                epoch_num = self.current_epoch
                out_filename = f"{base_name}_epoch_{epoch_num}.wav"
                out_filepath = os.path.join(self.save_dir, out_filename)
                save_wav(enhanced, 48000, out_filepath)

        return total_loss

    def on_train_epoch_end(self):
        sisdr_mean = torch.stack(self.train_sisdr_epoch).mean()
        stft_mean = torch.stack(self.train_stft_epoch).mean()
        total_mean = torch.stack(self.train_total_epoch).mean()

        self.train_sisdr_log.append(sisdr_mean.item())
        self.train_stft_log.append(stft_mean.item())
        self.train_total_log.append(total_mean.item())

        self.log('train_sisdr_epoch', sisdr_mean)
        self.log('train_stft_epoch', stft_mean)
        self.log('train_total_epoch', total_mean)

        current_lr = self.trainer.optimizers[0].param_groups[0]['lr']
        print(f"Epoch {self.current_epoch} - LR: {current_lr:.6f} | "
              f"Train SISDR: {sisdr_mean:.4f}, Train STFT: {stft_mean:.4f}, Train Total: {total_mean:.4f}")

        with open(self.log_file, "a") as f:
            f.write(f"[Train] Epoch {self.current_epoch} | LR: {current_lr:.6f} | "
                    f"SISDR: {sisdr_mean:.4f} | STFT: {stft_mean:.4f} | Total: {total_mean:.4f}\n")

        self.train_sisdr_epoch.clear()
        self.train_stft_epoch.clear()
        self.train_total_epoch.clear()

    def validation_step(self, batch, batch_idx):
        acc_data = batch['acc']
        clean_data = batch['clean']

        enh_audio = self(acc_data)
        sisdr_loss, stft_loss, total_loss = self.compute_losses(enh_audio, clean_data)

        self.val_sisdr_epoch.append(sisdr_loss)
        self.val_stft_epoch.append(stft_loss)
        self.val_total_epoch.append(total_loss)

        if self.save_sample_outputs and (batch_idx < 5):
            filenames = batch['filename']
            for i in range(acc_data.size(0)):
                enhanced = enh_audio[i].detach().cpu().numpy().squeeze()
                base_name = os.path.splitext(filenames[i])[0]
                epoch_num = self.current_epoch
                out_filename = f"{base_name}_epoch_{epoch_num}.wav"
                out_filepath = os.path.join(self.save_dir, out_filename)
                save_wav(enhanced, 48000, out_filepath)

        return total_loss

    def on_validation_epoch_end(self):
        sisdr_mean = torch.stack(self.val_sisdr_epoch).mean()
        stft_mean = torch.stack(self.val_stft_epoch).mean()
        total_mean = torch.stack(self.val_total_epoch).mean()

        self.val_sisdr_log.append(sisdr_mean.item())
        self.val_stft_log.append(stft_mean.item())
        self.val_total_log.append(total_mean.item())

        self.log('val_sisdr_epoch', sisdr_mean)
        self.log('val_stft_epoch', stft_mean)
        self.log('val_total_epoch', total_mean)

        print(f"Epoch {self.current_epoch} - "
              f"Val SISDR: {sisdr_mean:.4f}, Val STFT: {stft_mean:.4f}, Val Total: {total_mean:.4f}")

        with open(self.log_file, "a") as f:
            f.write(f"[Val]   Epoch {self.current_epoch} | "
                    f"SISDR: {sisdr_mean:.4f} | STFT: {stft_mean:.4f} | Total: {total_mean:.4f}\n")

        self.val_sisdr_epoch.clear()
        self.val_stft_epoch.clear()
        self.val_total_epoch.clear()

    def configure_optimizers(self):
        optimizer = torch.optim.Adam(
            self.parameters(),
            lr=1e-4,
            weight_decay=1e-5,
            betas=(0.5, 0.999)
        )
        scheduler = {
            'scheduler': torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(
                optimizer,
                T_0=10,
                T_mult=1,
                eta_min=0.0,
                last_epoch=-1
            ),
            'interval': 'epoch',
            'frequency': 1
        }
        return [optimizer], [scheduler]

class TQDMEpochProgressBar(Callback):
    def on_train_epoch_start(self, trainer, pl_module):
        trainer.epoch_progress = tqdm(
            total=trainer.num_training_batches,
            desc=f"Epoch {trainer.current_epoch + 1}/{trainer.max_epochs}",
            unit='batch',
            leave=False
        )

    def on_train_batch_end(self, trainer, pl_module, outputs, batch, batch_idx):
        if hasattr(trainer, 'epoch_progress'):
            trainer.epoch_progress.update(1)

    def on_train_epoch_end(self, trainer, pl_module):
        if hasattr(trainer, 'epoch_progress'):
            trainer.epoch_progress.close()
            del trainer.epoch_progress

class ResourceCleanupCallback(Callback):
    def on_train_epoch_end(self, trainer, pl_module):
        gc.collect()
        torch.cuda.empty_cache()

# --------------------- MAIN: training usage --------------------- #
if __name__ == "__main__":
    import sys

    model_name = 'DCCTN'
    batch_size = 8
    epochs = 100
    gpu_ids = [0]
    loss_function = 'SISDR+MultiResFreqLoss'
    
    # Point these to the directories created by data_preprocessing.py
    train_4s_dir = r"C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Train\4s_clips"
    dev_4s_dir   = r"C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Dev\4s_clips"

    # Check existence
    if not os.path.isdir(train_4s_dir):
        raise RuntimeError(f"Train directory {train_4s_dir} does not exist!")
    if not os.path.isdir(dev_4s_dir):
        raise RuntimeError(f"Dev directory {dev_4s_dir} does not exist!")

    # 1) Create model
    net = DCCTN()
    model = DeepLearningModel(net, batch_size=batch_size,
                              save_sample_outputs=True, save_dir='enhanced_samples')

    # 2) Create callbacks
    checkpoint_callback = ModelCheckpoint(
        monitor='val_total_epoch',
        dirpath=os.path.join(os.getcwd(), 'Saved_Models', model_name),
        filename=model_name + '-ACCEAR-' + loss_function + '-{epoch:02d}-{val_loss:.2f}',
        save_top_k=1,
        mode='min'
    )
    tqdm_callback = TQDMEpochProgressBar()
    cleanup_callback = ResourceCleanupCallback()
    callbacks = [checkpoint_callback, tqdm_callback, cleanup_callback]

    # 3) Create data loaders from the 4s clipped WAVs
    train_dataset = FourSecDataset(train_4s_dir)
    dev_dataset   = FourSecDataset(dev_4s_dir)

    train_loader = DataLoader(train_dataset, batch_size=batch_size,
                              shuffle=True, num_workers=0, pin_memory=True, drop_last=True)
    dev_loader   = DataLoader(dev_dataset, batch_size=batch_size,
                              shuffle=False, num_workers=0, pin_memory=True)

    # 4) Trainer
    trainer_kwargs = {
        'max_epochs': epochs,
        'accelerator': 'gpu' if torch.cuda.is_available() else 'cpu',
        'devices': [0],
        'callbacks': callbacks,
        'gradient_clip_val': 10,
        'accumulate_grad_batches': 2,
        'log_every_n_steps': 10,
        'precision': 32,
        'enable_checkpointing': True,
        'enable_progress_bar': True,
        'num_sanity_val_steps': 0
    }
    if len(gpu_ids) > 1 and torch.cuda.is_available():
        trainer_kwargs['strategy'] = 'ddp'

    trainer = pl.Trainer(**trainer_kwargs)
    trainer.fit(model, train_dataloaders=train_loader, val_dataloaders=dev_loader)

    # 5) Save "last epoch" model
    last_model_path = os.path.join(checkpoint_callback.dirpath, "model_last.ckpt")
    trainer.save_checkpoint(last_model_path)
    print("Training complete!")

    # 6) Plot or visualize losses if desired
    epochs_range = range(len(model.train_sisdr_log))
    plt.figure(figsize=(12, 8))

    plt.subplot(311)
    plt.plot(epochs_range, model.train_sisdr_log, 'b-o', label='Train SISDR')
    plt.plot(epochs_range, model.val_sisdr_log, 'r-o', label='Val SISDR')
    plt.title("SISDR Loss")
    plt.legend()
    plt.grid(True)

    plt.subplot(312)
    plt.plot(epochs_range, model.train_stft_log, 'b-o', label='Train STFT')
    plt.plot(epochs_range, model.val_stft_log, 'r-o', label='Val STFT')
    plt.title("MultiRes STFT Loss")
    plt.legend()
    plt.grid(True)

    plt.subplot(313)
    plt.plot(epochs_range, model.train_total_log, 'b-o', label='Train Total')
    plt.plot(epochs_range, model.val_total_log, 'r-o', label='Val Total')
    plt.title("Total Loss")
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    loss_plot_path = os.path.join(checkpoint_callback.dirpath, "loss_components_plot.png")
    plt.savefig(loss_plot_path)
    print(f"Saved loss plot to {loss_plot_path}")

    # 7) (Optional) Enhance dev set with best/last model and save

    best_model_path = checkpoint_callback.best_model_path
    print(f"Best model checkpoint path: {best_model_path}")

    best_model = DeepLearningModel.load_from_checkpoint(
        best_model_path,
        net=DCCTN()
    )
    best_model.eval().cuda()

    last_model = DeepLearningModel.load_from_checkpoint(
        last_model_path,
        net=DCCTN()
    )
    last_model.eval().cuda()

    def enhance_and_save(pl_model, dataset, out_folder):
        os.makedirs(out_folder, exist_ok=True)
        device = 'cuda' if torch.cuda.is_available() else 'cpu'
        pl_model.to(device)
        pl_model.eval()
        with torch.no_grad():
            for i in range(len(dataset)):
                sample = dataset[i]
                acc_data = sample['acc'].unsqueeze(0).to(device)
                enhanced = pl_model(acc_data)
                enhanced_np = enhanced.squeeze().cpu().numpy()
                base_name = os.path.splitext(sample['filename'])[0]
                save_path = os.path.join(out_folder, f"{base_name}.wav")
                save_wav(enhanced_np, 48000, save_path)

    dev_enh_best = os.path.join(checkpoint_callback.dirpath, "Enhanced_Best")
    dev_enh_last = os.path.join(checkpoint_callback.dirpath, "Enhanced_Last")

    print(f"Generating enhanced audio with best model into {dev_enh_best}...")
    enhance_and_save(best_model, dev_dataset, dev_enh_best)

    print(f"Generating enhanced audio with last model into {dev_enh_last}...")
    enhance_and_save(last_model, dev_dataset, dev_enh_last)

    print("Enhancement complete.")
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# INFO:numexpr.utils:Note: NumExpr detected 32 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name           | Type                    | Params | Mode
# -------------------------------------------------------------------
# 0 | model          | DCCTN                   | 61.6 M | train
# 1 | si_sdr_loss    | SISDRLoss               | 0      | train
# 2 | stft_loss_func | MultiResolutionSTFTLoss | 0      | train
# -------------------------------------------------------------------
# 61.5 M    Trainable params
# 132 K     Non-trainable params
# 61.6 M    Total params
# 246.335   Total estimated model params size (MB)
# 356       Modules in train mode
# 0         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# INFO:root:Saved WAV file: enhanced_samples\acc_p231_001_mic1_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p250_392_mic2_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p236_290_mic2_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p230_131_mic1_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p228_118_mic1_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p227_092_mic1_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p243_303_mic2_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p236_403_mic1_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p243_139_mic2_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p233_177_mic1_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p250_154_mic1_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p250_053_mic1_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p244_139_mic1_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p239_263_mic1_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p226_006_mic2_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p239_170_mic2_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p226_299_mic1_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p236_232_mic2_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p228_312_mic1_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p236_173_mic2_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p231_055_mic1_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p239_370_mic2_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p233_009_mic1_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p227_326_mic1_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p250_231_mic1_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p233_094_mic2_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p239_053_mic1_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p227_029_mic1_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p231_454_mic1_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p243_175_mic1_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p244_326_mic2_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p228_209_mic1_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p236_019_mic2_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p244_356_mic1_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p226_175_mic2_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p231_072_mic1_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p231_179_mic1_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p226_224_mic2_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p227_047_mic2_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p239_168_mic2_epoch_0.wav
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_001_mic1_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_001_mic2_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_002_mic1_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_002_mic2_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_003_mic1_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_003_mic2_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_004_mic1_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_004_mic2_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_005_mic1_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_005_mic2_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_006_mic1_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_006_mic2_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_007_mic1_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_007_mic2_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_008_mic1_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_008_mic2_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_009_mic1_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_009_mic2_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_010_mic1_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_010_mic2_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_011_mic1_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_011_mic2_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_012_mic1_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_012_mic2_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_013_mic1_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_013_mic2_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_014_mic1_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_014_mic2_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_015_mic1_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_015_mic2_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_016_mic1_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_016_mic2_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_017_mic1_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_017_mic2_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_018_mic1_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_018_mic2_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_019_mic1_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_019_mic2_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_020_mic1_epoch_0.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_020_mic2_epoch_0.wav
# Epoch 0 - Val SISDR: -9.0428, Val STFT: 1.7501, Val Total: -7.2926
# Epoch 0 - LR: 0.000098 | Train SISDR: -5.5317, Train STFT: 5.0772, Train Total: -0.4545
# INFO:root:Saved WAV file: enhanced_samples\acc_p227_013_mic2_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p239_233_mic1_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p236_434_mic2_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p227_161_mic1_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p239_441_mic2_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p226_279_mic2_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p228_357_mic2_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p239_159_mic2_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p239_378_mic1_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p239_287_mic1_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p239_433_mic2_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p244_145_mic1_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p226_167_mic1_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p243_148_mic2_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p239_186_mic2_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p239_418_mic2_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p250_095_mic2_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p226_059_mic1_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p230_166_mic2_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p230_272_mic2_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p250_422_mic1_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p230_087_mic1_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p226_231_mic2_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p250_438_mic1_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p231_198_mic2_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p230_387_mic1_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p227_238_mic1_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p227_220_mic2_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p228_110_mic1_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p250_489_mic1_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p250_246_mic1_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p227_025_mic1_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p236_170_mic2_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p230_298_mic1_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p230_126_mic1_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p250_357_mic1_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p250_100_mic1_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p226_313_mic1_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p227_244_mic1_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p236_288_mic2_epoch_1.wav
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_001_mic1_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_001_mic2_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_002_mic1_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_002_mic2_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_003_mic1_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_003_mic2_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_004_mic1_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_004_mic2_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_005_mic1_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_005_mic2_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_006_mic1_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_006_mic2_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_007_mic1_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_007_mic2_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_008_mic1_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_008_mic2_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_009_mic1_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_009_mic2_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_010_mic1_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_010_mic2_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_011_mic1_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_011_mic2_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_012_mic1_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_012_mic2_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_013_mic1_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_013_mic2_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_014_mic1_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_014_mic2_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_015_mic1_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_015_mic2_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_016_mic1_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_016_mic2_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_017_mic1_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_017_mic2_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_018_mic1_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_018_mic2_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_019_mic1_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_019_mic2_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_020_mic1_epoch_1.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_020_mic2_epoch_1.wav
# Epoch 1 - Val SISDR: -10.0011, Val STFT: 1.4069, Val Total: -8.5941
# Epoch 1 - LR: 0.000090 | Train SISDR: -8.9412, Train STFT: 1.6248, Train Total: -7.3164
# INFO:root:Saved WAV file: enhanced_samples\acc_p231_020_mic1_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p231_173_mic2_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p233_167_mic2_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p250_196_mic1_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p231_279_mic2_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p231_373_mic1_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p226_112_mic1_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p236_352_mic1_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p228_286_mic2_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p226_296_mic2_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p228_336_mic1_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p250_276_mic2_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p243_236_mic1_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p239_466_mic1_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p239_175_mic1_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p243_073_mic2_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p250_432_mic2_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p231_059_mic2_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p230_281_mic2_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p228_212_mic2_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p236_385_mic2_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p244_328_mic2_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p244_403_mic1_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p250_439_mic1_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p244_390_mic2_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p233_123_mic2_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p244_147_mic1_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p230_025_mic2_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p230_151_mic2_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p226_175_mic2_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p231_376_mic1_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p244_158_mic1_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p227_195_mic2_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p233_040_mic2_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p228_021_mic1_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p250_146_mic2_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p233_154_mic2_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p230_054_mic2_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p226_260_mic1_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p231_197_mic1_epoch_2.wav
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_001_mic1_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_001_mic2_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_002_mic1_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_002_mic2_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_003_mic1_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_003_mic2_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_004_mic1_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_004_mic2_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_005_mic1_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_005_mic2_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_006_mic1_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_006_mic2_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_007_mic1_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_007_mic2_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_008_mic1_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_008_mic2_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_009_mic1_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_009_mic2_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_010_mic1_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_010_mic2_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_011_mic1_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_011_mic2_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_012_mic1_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_012_mic2_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_013_mic1_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_013_mic2_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_014_mic1_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_014_mic2_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_015_mic1_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_015_mic2_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_016_mic1_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_016_mic2_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_017_mic1_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_017_mic2_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_018_mic1_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_018_mic2_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_019_mic1_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_019_mic2_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_020_mic1_epoch_2.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_020_mic2_epoch_2.wav
# Epoch 2 - Val SISDR: -10.2965, Val STFT: 1.2774, Val Total: -9.0190
# Epoch 2 - LR: 0.000079 | Train SISDR: -9.3447, Train STFT: 1.3825, Train Total: -7.9622
# INFO:root:Saved WAV file: enhanced_samples\acc_p231_360_mic2_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p250_120_mic1_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p233_186_mic2_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p230_292_mic2_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p250_137_mic2_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p231_219_mic2_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p243_036_mic1_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p227_321_mic2_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p227_159_mic2_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p231_067_mic2_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p227_399_mic2_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p250_016_mic1_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p226_238_mic1_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p228_099_mic1_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p233_375_mic2_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p230_324_mic2_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p228_253_mic1_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p228_009_mic1_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p243_321_mic1_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p243_352_mic1_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p233_214_mic2_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p233_014_mic2_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p228_088_mic2_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p250_096_mic2_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p226_317_mic1_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p231_285_mic1_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p244_114_mic2_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p243_391_mic2_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p239_384_mic2_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p230_076_mic2_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p236_048_mic1_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p250_118_mic1_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p227_380_mic2_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p239_349_mic1_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p227_160_mic1_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p228_131_mic1_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p239_222_mic2_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p243_152_mic2_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p243_378_mic1_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p244_330_mic1_epoch_3.wav
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_001_mic1_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_001_mic2_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_002_mic1_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_002_mic2_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_003_mic1_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_003_mic2_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_004_mic1_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_004_mic2_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_005_mic1_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_005_mic2_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_006_mic1_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_006_mic2_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_007_mic1_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_007_mic2_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_008_mic1_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_008_mic2_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_009_mic1_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_009_mic2_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_010_mic1_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_010_mic2_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_011_mic1_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_011_mic2_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_012_mic1_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_012_mic2_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_013_mic1_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_013_mic2_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_014_mic1_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_014_mic2_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_015_mic1_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_015_mic2_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_016_mic1_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_016_mic2_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_017_mic1_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_017_mic2_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_018_mic1_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_018_mic2_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_019_mic1_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_019_mic2_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_020_mic1_epoch_3.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_020_mic2_epoch_3.wav
# Epoch 3 - Val SISDR: -10.4802, Val STFT: 1.3002, Val Total: -9.1800
# Epoch 3 - LR: 0.000065 | Train SISDR: -9.5765, Train STFT: 1.2740, Train Total: -8.3025
# INFO:root:Saved WAV file: enhanced_samples\acc_p236_345_mic1_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p236_211_mic2_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p226_365_mic1_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p244_350_mic1_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p230_131_mic2_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p231_024_mic1_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p227_269_mic1_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p244_008_mic1_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p250_166_mic2_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p231_396_mic1_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p226_252_mic1_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p228_187_mic1_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p228_197_mic1_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p227_319_mic2_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p244_410_mic2_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p230_364_mic1_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p228_082_mic1_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p244_319_mic2_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p236_119_mic1_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p228_105_mic1_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p233_276_mic1_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p250_452_mic2_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p227_139_mic2_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p250_186_mic1_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p231_123_mic1_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p243_066_mic2_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p230_192_mic1_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p239_467_mic1_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p233_370_mic2_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p243_196_mic2_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p239_088_mic1_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p239_429_mic2_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p244_258_mic1_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p244_421_mic2_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p227_069_mic1_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p250_180_mic1_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p250_132_mic2_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p239_426_mic1_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p227_076_mic1_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p239_191_mic2_epoch_4.wav
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_001_mic1_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_001_mic2_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_002_mic1_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_002_mic2_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_003_mic1_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_003_mic2_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_004_mic1_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_004_mic2_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_005_mic1_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_005_mic2_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_006_mic1_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_006_mic2_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_007_mic1_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_007_mic2_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_008_mic1_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_008_mic2_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_009_mic1_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_009_mic2_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_010_mic1_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_010_mic2_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_011_mic1_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_011_mic2_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_012_mic1_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_012_mic2_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_013_mic1_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_013_mic2_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_014_mic1_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_014_mic2_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_015_mic1_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_015_mic2_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_016_mic1_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_016_mic2_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_017_mic1_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_017_mic2_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_018_mic1_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_018_mic2_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_019_mic1_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_019_mic2_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_020_mic1_epoch_4.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_020_mic2_epoch_4.wav
# Epoch 4 - Val SISDR: -10.6122, Val STFT: 1.2187, Val Total: -9.3934
# Epoch 4 - LR: 0.000050 | Train SISDR: -9.7381, Train STFT: 1.2149, Train Total: -8.5232
# INFO:root:Saved WAV file: enhanced_samples\acc_p231_422_mic2_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p239_321_mic2_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p226_110_mic2_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p228_023_mic1_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p228_182_mic1_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p236_186_mic2_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p230_107_mic1_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p250_284_mic1_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p228_343_mic2_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p244_376_mic2_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p228_168_mic2_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p226_352_mic2_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p228_174_mic2_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p231_417_mic1_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p244_257_mic2_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p244_298_mic2_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p233_111_mic2_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p233_284_mic2_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p250_286_mic2_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p226_070_mic2_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p227_044_mic1_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p226_267_mic2_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p227_166_mic1_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p250_058_mic1_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p233_275_mic1_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p244_020_mic2_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p236_491_mic1_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p236_184_mic2_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p231_231_mic2_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p231_344_mic1_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p239_012_mic1_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p243_019_mic2_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p239_444_mic2_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p243_364_mic1_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p239_154_mic1_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p244_260_mic1_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p231_139_mic1_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p250_341_mic1_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p233_118_mic2_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p230_176_mic2_epoch_5.wav
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_001_mic1_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_001_mic2_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_002_mic1_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_002_mic2_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_003_mic1_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_003_mic2_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_004_mic1_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_004_mic2_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_005_mic1_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_005_mic2_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_006_mic1_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_006_mic2_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_007_mic1_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_007_mic2_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_008_mic1_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_008_mic2_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_009_mic1_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_009_mic2_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_010_mic1_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_010_mic2_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_011_mic1_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_011_mic2_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_012_mic1_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_012_mic2_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_013_mic1_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_013_mic2_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_014_mic1_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_014_mic2_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_015_mic1_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_015_mic2_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_016_mic1_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_016_mic2_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_017_mic1_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_017_mic2_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_018_mic1_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_018_mic2_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_019_mic1_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_019_mic2_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_020_mic1_epoch_5.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_020_mic2_epoch_5.wav
# Epoch 5 - Val SISDR: -10.6659, Val STFT: 1.1351, Val Total: -9.5308
# Epoch 5 - LR: 0.000035 | Train SISDR: -9.8522, Train STFT: 1.1782, Train Total: -8.6740
# INFO:root:Saved WAV file: enhanced_samples\acc_p243_035_mic2_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p226_148_mic2_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p236_391_mic1_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p236_438_mic1_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p231_376_mic2_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p236_257_mic2_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p230_055_mic2_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p226_072_mic1_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p236_488_mic1_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p243_090_mic1_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p231_134_mic1_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p231_350_mic2_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p233_338_mic1_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p228_284_mic1_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p243_130_mic2_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p236_440_mic1_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p226_153_mic2_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p230_172_mic1_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p226_088_mic1_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p236_385_mic1_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p226_365_mic1_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p250_275_mic2_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p233_332_mic2_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p230_040_mic2_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p231_122_mic1_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p243_081_mic1_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p228_225_mic2_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p230_084_mic1_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p231_372_mic1_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p244_019_mic2_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p226_248_mic2_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p227_209_mic2_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p227_379_mic1_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p243_212_mic2_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p233_357_mic2_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p236_251_mic2_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p230_047_mic2_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p230_231_mic2_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p244_167_mic2_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p244_002_mic1_epoch_6.wav
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_001_mic1_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_001_mic2_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_002_mic1_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_002_mic2_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_003_mic1_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_003_mic2_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_004_mic1_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_004_mic2_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_005_mic1_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_005_mic2_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_006_mic1_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_006_mic2_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_007_mic1_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_007_mic2_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_008_mic1_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_008_mic2_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_009_mic1_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_009_mic2_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_010_mic1_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_010_mic2_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_011_mic1_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_011_mic2_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_012_mic1_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_012_mic2_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_013_mic1_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_013_mic2_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_014_mic1_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_014_mic2_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_015_mic1_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_015_mic2_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_016_mic1_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_016_mic2_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_017_mic1_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_017_mic2_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_018_mic1_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_018_mic2_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_019_mic1_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_019_mic2_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_020_mic1_epoch_6.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_020_mic2_epoch_6.wav
# Epoch 6 - Val SISDR: -10.7123, Val STFT: 1.1328, Val Total: -9.5795
# Epoch 6 - LR: 0.000021 | Train SISDR: -9.9371, Train STFT: 1.1546, Train Total: -8.7826
# INFO:root:Saved WAV file: enhanced_samples\acc_p228_276_mic1_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p227_138_mic1_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p243_064_mic2_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p233_038_mic1_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p250_288_mic1_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p230_032_mic1_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p239_377_mic2_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p227_347_mic2_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p250_386_mic1_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p236_495_mic1_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p250_424_mic1_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p250_369_mic1_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p226_175_mic2_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p244_262_mic2_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p236_029_mic1_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p233_109_mic2_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p243_340_mic1_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p231_252_mic2_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p231_451_mic1_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p250_318_mic2_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p230_342_mic2_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p236_226_mic2_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p244_241_mic1_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p227_049_mic2_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p228_141_mic2_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p227_238_mic1_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p230_330_mic2_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p226_297_mic1_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p228_310_mic2_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p243_019_mic1_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p233_334_mic1_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p236_111_mic2_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p226_093_mic1_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p231_162_mic1_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p233_061_mic2_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p236_488_mic1_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p228_148_mic2_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p233_109_mic1_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p231_172_mic2_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p244_108_mic2_epoch_7.wav
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_001_mic1_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_001_mic2_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_002_mic1_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_002_mic2_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_003_mic1_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_003_mic2_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_004_mic1_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_004_mic2_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_005_mic1_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_005_mic2_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_006_mic1_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_006_mic2_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_007_mic1_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_007_mic2_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_008_mic1_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_008_mic2_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_009_mic1_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_009_mic2_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_010_mic1_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_010_mic2_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_011_mic1_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_011_mic2_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_012_mic1_epoch_7.wav
# INFO:root:Saved WAV file: enhanced_samples\acc_p232_012_mic2_epoch_7.wav
# ...
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_354_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_355_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_355_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_356_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_356_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_357_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_357_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_358_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_358_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_359_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_359_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_360_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_360_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_361_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_361_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_362_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_362_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_363_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_363_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_364_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_364_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_365_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_365_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_366_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_366_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_367_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_367_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_368_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_368_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_369_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_369_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_370_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_370_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_371_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_371_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_372_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_372_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_373_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_373_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_374_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_374_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_375_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_375_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_376_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_376_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_377_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_377_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_378_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_378_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_379_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_379_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_380_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_380_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_381_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_381_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_382_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_382_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_383_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_383_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_384_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_384_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_385_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_385_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_386_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_386_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_387_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_387_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_388_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_388_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_389_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_389_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_390_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_390_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_391_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_391_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_392_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_392_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_393_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_393_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_394_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_394_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_395_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_395_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_396_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_396_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_397_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_397_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_398_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_398_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_399_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_399_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_400_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_400_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_401_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_401_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_402_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_402_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_403_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_403_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_404_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_404_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_405_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_405_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_406_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_406_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_407_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_407_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_408_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_408_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_409_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_409_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_410_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_410_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_411_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_411_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_412_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_412_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_413_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_413_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_414_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_414_mic2.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_415_mic1.wav
# INFO:root:Saved WAV file: C:\Users\Anomadarshi\Desktop\VCTK_down_upsample\Saved_Models\DCCTN\Enhanced_Last\acc_p232_415_mic2.wav
# Enhancement complete.
